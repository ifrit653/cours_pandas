# %%
import pandas as pd
import numpy as np

# %%
n = np.random.randint(low = 0, high = 1000, size = (5,3))
n
# Out:
# array([[497, 333, 143],
#        [950, 771, 803],
#        [ 47, 411, 144],
#        [216,  31, 466],
#        [118, 338,  68]])

# %%
a = ["A", "B", "C"]
df = pd.DataFrame(data = n, columns = a, index = ['ligne 1', 'ligne 2','ligne 3','ligne 4','ligne 5'])
df
# Out:
#            A    B    C
# ligne 1  497  333  143
# ligne 2  950  771  803
# ligne 3   47  411  144
# ligne 4  216   31  466
# ligne 5  118  338   68

# %%
df["B"]
# Out:
# ligne 1    333
# ligne 2    771
# ligne 3    411
# ligne 4     31
# ligne 5    338
# Name: B, dtype: int64

# %%
df.iloc[[2]]
# Out:
#           A    B    C
# ligne 3  47  411  144

# %%
df["C"][2]
# Out:
# 144

# %%
df["C"][2] = 4
df
# Out:
#            A    B    C
# ligne 1  497  333  143
# ligne 2  950  771  803
# ligne 3   47  411    4
# ligne 4  216   31  466
# ligne 5  118  338   68

# %%
df[2:]
# Out:
#            A    B    C
# ligne 3   47  411    4
# ligne 4  216   31  466
# ligne 5  118  338   68

# %%
df.iloc[-2:, -2:]
# Out:
#            B    C
# ligne 4   31  466
# ligne 5  338   68

# %%
df.iloc[-2:]
# Out:
#            A    B    C
# ligne 4  216   31  466
# ligne 5  118  338   68

# %%
df["D"] = [2,333,4545,34343,222]

# %%
df
# Out:
#            A    B    C      D
# ligne 1  497  333  143      2
# ligne 2  950  771  803    333
# ligne 3   47  411    4   4545
# ligne 4  216   31  466  34343
# ligne 5  118  338   68    222

# %%
df.iloc[-2:, 1:]
# Out:
#            B    C      D
# ligne 4   31  466  34343
# ligne 5  338   68    222
